# %% [markdown]
# ANALISIS RIB
# ---

# %%
from monstry.Builder import Builder
from monstry.DataCleaner import DataCleaner

# %%
config_json = './rib_data/config/config.json'
builder = Builder( config_path = config_json)
# Out:
# Se ha creado usando un archivo de configuracion

# %%
rib_analisis = DataCleaner(builder, 'rib_ru_identificacion' )
# Out:
# Se ha cargado efectivamente el dataframe
#
#         Informacion:
#             _ get_completitud():
#                 Se obtienen la completutid de la tabla
#             - get_exactitud():
#                 Se obtiene la exactitud de la tabla siempre y cuando los valores por default sean completados
#                 en el archivo de configuraciones o tengan un valor por defecto
#             ----------------------------------------------------------------------------------------------------
#             - get_resumen():
#                 Se obtiene un dataframe con el análisis de completitud y exactitud del dataset seleccionado

# %%
rib_analisis.get_completitud()
rib_analisis.completitud.to_csv('completitud.csv')
# Out:
# Analisis de completitud realizado teniendo en cuenta los valores por default
# Analisis de completitud finalizado
#  * Para observar los resultados solo de "Completitud" visualizar con .completitud
#                      COLUMNA           NOMBRE TABLA  REGISTROS TOTALES  \
# 0   insert_into_dl_timestamp  rib_ru_identificacion             100000
# 1   notificacion_electronica  rib_ru_identificacion             100000
# 2                      apodo  rib_ru_identificacion             100000
# 3        fecha_creacion_beca  rib_ru_identificacion             100000
# 4        fecha_creacion_ts_2  rib_ru_identificacion             100000
# ..                       ...                    ...                ...
# 71          fecha_nacimiento  rib_ru_identificacion             100000
# 72                    nombre  rib_ru_identificacion             100000
# 73                  apellido  rib_ru_identificacion             100000
# ...

# %%
rib_analisis.completitud.to_csv('completitud.csv')

# %%
rib_analisis.get_exactitud()
rib_analisis.exactitud
# Out:
# Analisis de completitud realizado teniendo en cuenta los valores por default
# Analisis de completitud finalizado
#  * Para observar los resultados solo de "Completitud" visualizar con .completitud
# Se están usando valores por default para la validación de los datos
# Para usar funciones customizadas de validación se deben determinar en el archivo de configuración json
# El dataframe no contiene registros para analizar
# El dataframe no contiene registros para analizar
# El dataframe no contiene registros para analizar
# El dataframe no contiene registros para analizar
# El dataframe no contiene registros para analizar
# El dataframe no contiene registros para analizar
# El dataframe no contiene registros para analizar
# ⚠️WARNING:
# 	LA COLUMNA "numero_licencia_conducir" ES COMPLETAMENTE NULA, POR LO TANTO VALOR DE EXACTITUD ES SETEADO A 0
# ⚠️WARNING:
# 	LA COLUMNA "clase_licencia_conducir" ES COMPLETAMENTE NULA, POR LO TANTO VALOR DE EXACTITUD ES SETEADO A 0
# ⚠️WARNING:
# ...

# %%
rib_analisis.get_resumen()
# Out:
# Analisis de completitud realizado teniendo en cuenta los valores por default
# Analisis de completitud finalizado
#  * Para observar los resultados solo de "Completitud" visualizar con .completitud
# Se están usando valores por default para la validación de los datos
# Para usar funciones customizadas de validación se deben determinar en el archivo de configuración json
# El dataframe no contiene registros para analizar
# El dataframe no contiene registros para analizar
# El dataframe no contiene registros para analizar
# El dataframe no contiene registros para analizar
# El dataframe no contiene registros para analizar
# El dataframe no contiene registros para analizar
# El dataframe no contiene registros para analizar
# ⚠️WARNING:
# 	LA COLUMNA "numero_licencia_conducir" ES COMPLETAMENTE NULA, POR LO TANTO VALOR DE EXACTITUD ES SETEADO A 0
# ⚠️WARNING:
# 	LA COLUMNA "clase_licencia_conducir" ES COMPLETAMENTE NULA, POR LO TANTO VALOR DE EXACTITUD ES SETEADO A 0
# ⚠️WARNING:
# ...

# %%
rib_analisis.data_columnas()
# Out:
# El dataframe no contiene registros para analizar
# El dataframe no contiene registros para analizar
# El dataframe no contiene registros para analizar
# El dataframe no contiene registros para analizar
# El dataframe no contiene registros para analizar
# El dataframe no contiene registros para analizar
# El dataframe no contiene registros para analizar
# [{'data': 'number',
#   'dtype': 'int64',
#   'type': 'int',
#   'default': <function monstry.modules.funciones_generales.comprobando_numeros(variable)>,
#   'columna': 'id_identificacion',
#   'sample': '1028592'},
#  {'data': 'decimal',
#   'dtype': 'float64',
#   'type': 'float',
#   'default': <function monstry.modules.funciones_generales.comprobando_decimales(variable)>,
#   'columna': 'numero_documento',
#   'sample': '21337246.0'},
#  {'data': 'string',
#   'dtype': 'object',
#   'type': 'str',
#   'default': <function monstry.modules.funciones_generales.comprobando_strings(variable)>,
#   'columna': 'apellido',
# ...

# %%
from functools import reduce 

reduce( lambda col_a,col_b: {**col_a,**col_b}, [ {data['columna']: data['dtype']} for data in rib_analisis.data_columnas()])
# Out:
# El dataframe no contiene registros para analizar
# El dataframe no contiene registros para analizar
# El dataframe no contiene registros para analizar
# El dataframe no contiene registros para analizar
# El dataframe no contiene registros para analizar
# El dataframe no contiene registros para analizar
# El dataframe no contiene registros para analizar
# {'id_identificacion': 'int64',
#  'numero_documento': 'float64',
#  'apellido': 'object',
#  'nombre': 'object',
#  'fecha_nacimiento': 'datetime64',
#  'edad': 'float64',
#  'telefono': 'int64',
#  'telefono_alternativo': 'int64',
#  'correo_electronico': 'object',
#  'observaciones': 'object',
#  'cuil': 'float64',
#  'fk_sexo': 'float64',
#  'fk_situacion_conyugal': 'float64',
#  'fk_tipo_documento': 'float64',
#  'fecha_nacimiento_aproximada': 'float64',
#  'fk_nacionalidad': 'float64',
#  'fk_pais_anterior': 'float64',
#  'anio_ingreso_pais': 'float64',
#  'anios_residencia_caba': 'float64',
# ...
